# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import cv2
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, Dropout, Flatten,Conv2D, MaxPooling2D,BatchNormalization,AveragePooling2D
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from IPython.display import SVG
# from tensorflow.keras.utils.vis_utils import model_to_dot
import tensorflow.keras.backend as K 
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load Data

(X_train, y_train), (X_test,y_test) = datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step

# %%
CLASS_NAMES= ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
X_train = X_train.astype('float32') / 255.
X_test = X_test.astype('float32') / 255.

# %%
#Train-validation-test split

X_val, y_val = X_train[:5000], y_train[:5000]
X_train, y_train = X_train[5000:], y_train[5000:]

# %%
#Onehot Encoding the labels.

from sklearn.utils.multiclass import unique_labels
from tensorflow.keras.utils import to_categorical

# %%
#Since we have 10 classes we should expect the shape[1] of y_train,y_val and y_test to change from 1 to 10

y_train=to_categorical(y_train)
y_val=to_categorical(y_val)
y_test=to_categorical(y_test)

# %%
# def add_noise_and_clip_data(data):
#    noise = np.random.normal(loc=0.0, scale=0.1, size=data.shape)
#    data = data + noise
#    data = np.clip(data, 0., 1.)
#    return data

# %%
# X_train_noisy = add_noise_and_clip_data(X_train)
# X_test_noisy = add_noise_and_clip_data(X_test)
# X_val_noisy = add_noise_and_clip_data(X_val)

# %%
# idx = 4
# plt.subplot(1,2,1)
# plt.imshow(X_train[idx])
# plt.title('Original image')
# plt.subplot(1,2,2)
# plt.imshow(X_train_noisy[idx])
# plt.title('Image with noise')
# plt.show()

# %%
#Image Data Augmentation

# from tensorflow.keras.preprocessing.image import ImageDataGenerator

# train_generator = ImageDataGenerator(rotation_range=2, horizontal_flip=True,zoom_range=.1 )

# val_generator = ImageDataGenerator(rotation_range=2, horizontal_flip=True,zoom_range=.1)

# test_generator = ImageDataGenerator(rotation_range=2, horizontal_flip= True,zoom_range=.1)

# %%
#Fitting the augmentation defined above to the data

# train_generator.fit(X_train)
# val_generator.fit(X_val)
# test_ds = test_generator.fit(X_test)

# %%
ROWS = 32
COLS = 32
CHANNELS = 3
CLASSES = 10

# %%
def identity_block(X, f, filters, stage, block):
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    # Retrieve Filters
    F1, F2, F3 = filters

    # Save the input value. We'll need this later to add back to the main path. 
    X_shortcut = X

    # First component of main path
    X = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    # Second component of main path
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path
    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
from tensorflow.python.framework import ops
ops.reset_default_graph()

# tf.reset_default_graph()

with tf.compat.v1.Session() as test:
    A_prev = tf.compat.v1.placeholder("float", [3, 4, 4, 6])
    X = np.random.randn(3, 4, 4, 6)
    A = identity_block(A_prev, f = 2, filters = [2, 4, 6], stage = 1, block = 'a')
    test.run(tf.compat.v1.global_variables_initializer())
    out = test.run([A], feed_dict={A_prev: X, K.learning_phase(): 0})
    print("out = ", out[0][1][1][0])
# Out:
# out =  [0.62643826 0.         1.2405448  0.         0.         1.0372869 ]

# %%
def convolutional_block(X, f, filters, stage, block, s = 2):
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X


    ##### MAIN PATH #####
    # First component of main path 
    X = Conv2D(F1, (1, 1), strides = (s,s), name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    # Second component of main path
    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path
    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    
    ##### SHORTCUT PATH ####
    X_shortcut = Conv2D(F3, (1, 1), strides = (s,s), name = conv_name_base + '1', kernel_initializer = glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3, name = bn_name_base + '1')(X_shortcut)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X

# %%
from tensorflow.python.framework import ops
ops.reset_default_graph()

# tf.reset_default_graph()

with tf.compat.v1.Session() as test:
    A_prev = tf.compat.v1.placeholder("float", [3, 4, 4, 6])
    X = np.random.randn(3, 4, 4, 6)
    A = convolutional_block(A_prev, f = 2, filters = [2, 4, 6], stage = 1, block = 'a')
    test.run(tf.compat.v1.global_variables_initializer())
    out = test.run([A], feed_dict={A_prev: X, K.learning_phase(): 0})
    print("out = ",out[0][1][1][0])
# Out:
# out =  [2.274008   0.         0.22034594 0.         0.         0.        ]

# %%
def ResNet50(input_shape = (32, 32, 3), classes = 10):   
    global model
    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)
    
    # Stage 1
    X = Conv2D(64, (7, 7), strides = (2, 2), name = 'conv1', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convolutional_block(X, f = 3, filters = [64, 64, 256], stage = 2, block='a', s = 1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')

    # Stage 3
    X = convolutional_block(X, f = 3, filters = [128, 128, 512], stage = 3, block='a', s = 2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')

    # Stage 4
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], stage = 4, block='a', s = 2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')

    # Stage 5
    # X = convolutional_block(X, f = 3, filters = [512, 512, 2048], stage = 5, block='a', s = 2)
    # X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    # X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')

    # AVGPOOL.
    X = AveragePooling2D((2, 2), name='avg_pool')(X)

    # output layer
    X = Flatten()(X)
    X = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = glorot_uniform(seed=0))(X)
    
    # Create model
    model = Model(inputs = X_input, outputs = X, name='ResNet50')

    model.summary()

    return model

# %%
model = ResNet50(input_shape = (32, 32, 3), classes = 10)
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 38, 38, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 16, 16, 64)   9472        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 16, 16, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 7, 7, 64)     0           activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 7, 7, 64)     4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 7, 7, 64)     256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 7, 7, 64)     0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 7, 7, 64)     36928       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 7, 7, 64)     256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 7, 7, 64)     0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 7, 7, 256)    16640       activation_5[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 7, 7, 256)    16640       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 7, 7, 256)    1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 7, 7, 256)    1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 7, 7, 256)    0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 7, 7, 256)    0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 7, 7, 64)     16448       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 7, 7, 64)     256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 7, 7, 64)     0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 7, 7, 64)     36928       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 7, 7, 64)     256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 7, 7, 64)     0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 7, 7, 256)    16640       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 7, 7, 256)    1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 7, 7, 256)    0           bn2b_branch2c[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 7, 7, 256)    0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 7, 7, 64)     16448       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 7, 7, 64)     256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 7, 7, 64)     0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 7, 7, 64)     36928       activation_10[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 7, 7, 64)     256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 7, 7, 64)     0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 7, 7, 256)    16640       activation_11[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 7, 7, 256)    1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 7, 7, 256)    0           bn2c_branch2c[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 7, 7, 256)    0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 4, 4, 128)    32896       activation_12[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 4, 4, 128)    512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 4, 4, 128)    0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 4, 4, 128)    147584      activation_13[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 4, 4, 128)    512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 4, 4, 128)    0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 4, 4, 512)    66048       activation_14[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 4, 4, 512)    131584      activation_12[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 4, 4, 512)    2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 4, 4, 512)    2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 4, 4, 512)    0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 4, 4, 512)    0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 4, 4, 128)    65664       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 4, 4, 128)    512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 4, 4, 128)    0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 4, 4, 128)    147584      activation_16[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 4, 4, 128)    512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 4, 4, 128)    0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 4, 4, 512)    66048       activation_17[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 4, 4, 512)    2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 4, 4, 512)    0           bn3b_branch2c[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 4, 4, 512)    0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 4, 4, 128)    65664       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 4, 4, 128)    512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 4, 4, 128)    0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 4, 4, 128)    147584      activation_19[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 4, 4, 128)    512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 4, 4, 128)    0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 4, 4, 512)    66048       activation_20[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 4, 4, 512)    2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 512)    0           bn3c_branch2c[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 4, 4, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 4, 4, 128)    65664       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 4, 4, 128)    512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 4, 4, 128)    0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 4, 4, 128)    147584      activation_22[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 4, 4, 128)    512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 4, 4, 128)    0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 4, 4, 512)    66048       activation_23[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 4, 4, 512)    2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4, 4, 512)    0           bn3d_branch2c[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 4, 4, 512)    0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 2, 2, 256)    131328      activation_24[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 2, 2, 256)    1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 2, 2, 256)    0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 2, 2, 256)    590080      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 2, 2, 256)    1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 2, 2, 256)    0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 2, 2, 1024)   263168      activation_26[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 2, 2, 1024)   525312      activation_24[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 2, 2, 1024)   4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 2, 2, 1024)   4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 2, 2, 1024)   0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 2, 2, 1024)   0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 2, 2, 256)    262400      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 2, 2, 256)    1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 2, 2, 256)    0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 2, 2, 256)    590080      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 2, 2, 256)    1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 2, 2, 256)    0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 2, 2, 1024)   263168      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 2, 2, 1024)   4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 2, 2, 1024)   0           bn4b_branch2c[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 2, 2, 1024)   0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 2, 2, 256)    262400      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 2, 2, 256)    1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 2, 2, 256)    0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 2, 2, 256)    590080      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 2, 2, 256)    1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 2, 2, 256)    0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 2, 2, 1024)   263168      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 2, 2, 1024)   4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 2, 2, 1024)   0           bn4c_branch2c[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 2, 2, 1024)   0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 2, 2, 256)    262400      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 2, 2, 256)    1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 2, 2, 256)    0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 2, 2, 256)    590080      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 2, 2, 256)    1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 2, 2, 256)    0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 2, 2, 1024)   263168      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 2, 2, 1024)   4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 2, 2, 1024)   0           bn4d_branch2c[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 2, 2, 1024)   0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 2, 2, 256)    262400      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 2, 2, 256)    1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 2, 2, 256)    0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 2, 2, 256)    590080      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 2, 2, 256)    1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 2, 2, 256)    0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 2, 2, 1024)   263168      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 2, 2, 1024)   4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 2, 2, 1024)   0           bn4e_branch2c[0][0]
#                                                                  activation_36[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 2, 2, 1024)   0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 2, 2, 256)    262400      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 2, 2, 256)    1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 2, 2, 256)    0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 2, 2, 256)    590080      activation_40[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 2, 2, 256)    1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 2, 2, 256)    0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 2, 2, 1024)   263168      activation_41[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 2, 2, 1024)   4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 2, 2, 1024)   0           bn4f_branch2c[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 2, 2, 1024)   0           add_13[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 1024)   0           activation_42[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# fc10 (Dense)                    (None, 10)           10250       flatten[0][0]
# ==================================================================================================
# Total params: 8,599,434
# Trainable params: 8,568,842
# Non-trainable params: 30,592
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data = (X_val, y_val), 
                    epochs = 100,
                    batch_size = 64)
# Out:
# Epoch 1/100
# 704/704 [==============================] - 60s 78ms/step - loss: 2.3847 - accuracy: 0.3208 - val_loss: 2.6175 - val_accuracy: 0.3082
# Epoch 2/100
# 704/704 [==============================] - 53s 75ms/step - loss: 1.6259 - accuracy: 0.4537 - val_loss: 11.7947 - val_accuracy: 0.2996
# Epoch 3/100
# 704/704 [==============================] - 53s 75ms/step - loss: 1.5251 - accuracy: 0.4635 - val_loss: 1.2713 - val_accuracy: 0.5350
# Epoch 4/100
# 704/704 [==============================] - 53s 75ms/step - loss: 1.1298 - accuracy: 0.6024 - val_loss: 1.2329 - val_accuracy: 0.5666
# Epoch 5/100
# 704/704 [==============================] - 53s 75ms/step - loss: 1.0127 - accuracy: 0.6475 - val_loss: 1.1879 - val_accuracy: 0.5848
# Epoch 6/100
# 704/704 [==============================] - 53s 75ms/step - loss: 1.0375 - accuracy: 0.6418 - val_loss: 1.3703 - val_accuracy: 0.5614
# Epoch 7/100
# 704/704 [==============================] - 53s 75ms/step - loss: 1.1345 - accuracy: 0.6263 - val_loss: 0.9842 - val_accuracy: 0.6544
# Epoch 8/100
# 704/704 [==============================] - 53s 75ms/step - loss: 0.7559 - accuracy: 0.7386 - val_loss: 1.2459 - val_accuracy: 0.6316
# Epoch 9/100
# 704/704 [==============================] - 53s 75ms/step - loss: 0.7161 - accuracy: 0.7547 - val_loss: 1.1507 - val_accuracy: 0.6548
# Epoch 10/100
# 704/704 [==============================] - 53s 75ms/step - loss: 0.7089 - accuracy: 0.7577 - val_loss: 0.8514 - val_accuracy: 0.7110
# Epoch 11/100
# 704/704 [==============================] - 53s 75ms/step - loss: 0.5567 - accuracy: 0.8100 - val_loss: 2.8845 - val_accuracy: 0.2602
# Epoch 12/100
# 704/704 [==============================] - 53s 75ms/step - loss: 1.1091 - accuracy: 0.6545 - val_loss: 1.1192 - val_accuracy: 0.6368
# Epoch 13/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.5290 - accuracy: 0.8158 - val_loss: 0.8687 - val_accuracy: 0.7112
# Epoch 14/100
# 704/704 [==============================] - 54s 76ms/step - loss: 0.4007 - accuracy: 0.8636 - val_loss: 1.2581 - val_accuracy: 0.6254
# Epoch 15/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.3606 - accuracy: 0.8770 - val_loss: 0.8940 - val_accuracy: 0.7282
# Epoch 16/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.4459 - accuracy: 0.8474 - val_loss: 1.0545 - val_accuracy: 0.6984
# Epoch 17/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.2616 - accuracy: 0.9169 - val_loss: 1.4321 - val_accuracy: 0.6312
# Epoch 18/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.6430 - accuracy: 0.7910 - val_loss: 1.2602 - val_accuracy: 0.6700
# Epoch 19/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.2142 - accuracy: 0.9267 - val_loss: 0.9630 - val_accuracy: 0.7402
# Epoch 20/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.2073 - accuracy: 0.9347 - val_loss: 0.9947 - val_accuracy: 0.7284
# Epoch 21/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.2951 - accuracy: 0.9050 - val_loss: 0.9633 - val_accuracy: 0.7556
# Epoch 22/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.1364 - accuracy: 0.9578 - val_loss: 1.3860 - val_accuracy: 0.7052
# Epoch 23/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.1409 - accuracy: 0.9549 - val_loss: 1.1034 - val_accuracy: 0.7442
# Epoch 24/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0751 - accuracy: 0.9754 - val_loss: 1.2431 - val_accuracy: 0.7266
# Epoch 25/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0807 - accuracy: 0.9712 - val_loss: 1.2527 - val_accuracy: 0.7440
# Epoch 26/100
# 704/704 [==============================] - 54s 77ms/step - loss: 0.1302 - accuracy: 0.9587 - val_loss: 1.2640 - val_accuracy: 0.7140
# Epoch 27/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.1964 - accuracy: 0.9350 - val_loss: 1.8797 - val_accuracy: 0.6516
# Epoch 28/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.6849 - accuracy: 0.8073 - val_loss: 1.0216 - val_accuracy: 0.7396
# Epoch 29/100
# 704/704 [==============================] - 54s 76ms/step - loss: 0.1003 - accuracy: 0.9704 - val_loss: 1.1935 - val_accuracy: 0.7444
# Epoch 30/100
# 704/704 [==============================] - 54s 76ms/step - loss: 0.2066 - accuracy: 0.9384 - val_loss: 1.2713 - val_accuracy: 0.7272
# Epoch 31/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.1406 - accuracy: 0.9545 - val_loss: 1.2877 - val_accuracy: 0.7468
# Epoch 32/100
# 704/704 [==============================] - 53s 75ms/step - loss: 0.0381 - accuracy: 0.9885 - val_loss: 1.6246 - val_accuracy: 0.7068
# Epoch 33/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.3980 - accuracy: 0.8786 - val_loss: 1.5412 - val_accuracy: 0.6628
# Epoch 34/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.1398 - accuracy: 0.9590 - val_loss: 1.2042 - val_accuracy: 0.7572
# Epoch 35/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0418 - accuracy: 0.9884 - val_loss: 1.4984 - val_accuracy: 0.7330
# Epoch 36/100
# 704/704 [==============================] - 53s 75ms/step - loss: 0.1629 - accuracy: 0.9511 - val_loss: 1.2727 - val_accuracy: 0.7502
# Epoch 37/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.1072 - accuracy: 0.9668 - val_loss: 2.0799 - val_accuracy: 0.6634
# Epoch 38/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.1208 - accuracy: 0.9624 - val_loss: 1.7982 - val_accuracy: 0.6666
# Epoch 39/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.1326 - accuracy: 0.9580 - val_loss: 1.2761 - val_accuracy: 0.7526
# Epoch 40/100
# 704/704 [==============================] - 53s 75ms/step - loss: 0.0357 - accuracy: 0.9886 - val_loss: 1.4744 - val_accuracy: 0.7500
# Epoch 41/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0368 - accuracy: 0.9884 - val_loss: 1.5027 - val_accuracy: 0.7298
# Epoch 42/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0569 - accuracy: 0.9826 - val_loss: 1.4822 - val_accuracy: 0.7300
# Epoch 43/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.1625 - accuracy: 0.9511 - val_loss: 1.4190 - val_accuracy: 0.7186
# Epoch 44/100
# 704/704 [==============================] - 54s 76ms/step - loss: 0.1063 - accuracy: 0.9694 - val_loss: 1.2702 - val_accuracy: 0.7654
# Epoch 45/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0190 - accuracy: 0.9946 - val_loss: 2.1132 - val_accuracy: 0.6814
# Epoch 46/100
# 704/704 [==============================] - 54s 76ms/step - loss: 0.0903 - accuracy: 0.9706 - val_loss: 1.4473 - val_accuracy: 0.7390
# Epoch 47/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0227 - accuracy: 0.9932 - val_loss: 1.5360 - val_accuracy: 0.7382
# Epoch 48/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0453 - accuracy: 0.9850 - val_loss: 1.3966 - val_accuracy: 0.7470
# Epoch 49/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0295 - accuracy: 0.9903 - val_loss: 1.5985 - val_accuracy: 0.7302
# Epoch 50/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.1109 - accuracy: 0.9649 - val_loss: 1.3959 - val_accuracy: 0.7540
# Epoch 51/100
# 704/704 [==============================] - 54s 76ms/step - loss: 0.0279 - accuracy: 0.9920 - val_loss: 1.5888 - val_accuracy: 0.7436
# Epoch 52/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.1405 - accuracy: 0.9588 - val_loss: 1.3072 - val_accuracy: 0.7672
# Epoch 53/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0741 - accuracy: 0.9801 - val_loss: 1.3450 - val_accuracy: 0.7474
# Epoch 54/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0970 - accuracy: 0.9746 - val_loss: 1.4910 - val_accuracy: 0.7384
# Epoch 55/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.2102 - accuracy: 0.9368 - val_loss: 1.2103 - val_accuracy: 0.7564
# Epoch 56/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0116 - accuracy: 0.9974 - val_loss: 1.2914 - val_accuracy: 0.7672
# Epoch 57/100
# 704/704 [==============================] - 54s 76ms/step - loss: 0.0277 - accuracy: 0.9947 - val_loss: 1.4517 - val_accuracy: 0.7562
# Epoch 58/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0100 - accuracy: 0.9975 - val_loss: 1.8685 - val_accuracy: 0.7142
# Epoch 59/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.3545 - accuracy: 0.9038 - val_loss: 1.1581 - val_accuracy: 0.7576
# Epoch 60/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0241 - accuracy: 0.9945 - val_loss: 1.3800 - val_accuracy: 0.7492
# Epoch 61/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0180 - accuracy: 0.9950 - val_loss: 1.4242 - val_accuracy: 0.7628
# Epoch 62/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0200 - accuracy: 0.9948 - val_loss: 1.5180 - val_accuracy: 0.7664
# Epoch 63/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0085 - accuracy: 0.9974 - val_loss: 1.6862 - val_accuracy: 0.7514
# Epoch 64/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0531 - accuracy: 0.9848 - val_loss: 1.5382 - val_accuracy: 0.7578
# Epoch 65/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0669 - accuracy: 0.9822 - val_loss: 1.5290 - val_accuracy: 0.7444
# Epoch 66/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0927 - accuracy: 0.9759 - val_loss: 1.4094 - val_accuracy: 0.7586
# Epoch 67/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0256 - accuracy: 0.9934 - val_loss: 1.6012 - val_accuracy: 0.7324
# Epoch 68/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0321 - accuracy: 0.9892 - val_loss: 1.6744 - val_accuracy: 0.7308
# Epoch 69/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0187 - accuracy: 0.9940 - val_loss: 2.0337 - val_accuracy: 0.7080
# Epoch 70/100
# 704/704 [==============================] - 53s 75ms/step - loss: 0.0626 - accuracy: 0.9822 - val_loss: 1.5283 - val_accuracy: 0.7474
# Epoch 71/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0238 - accuracy: 0.9922 - val_loss: 1.5449 - val_accuracy: 0.7434
# Epoch 72/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0359 - accuracy: 0.9883 - val_loss: 1.5108 - val_accuracy: 0.7534
# Epoch 73/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0121 - accuracy: 0.9959 - val_loss: 1.5845 - val_accuracy: 0.7544
# Epoch 74/100
# 704/704 [==============================] - 54s 77ms/step - loss: 0.0446 - accuracy: 0.9863 - val_loss: 1.5921 - val_accuracy: 0.7308
# Epoch 75/100
# 704/704 [==============================] - 54s 76ms/step - loss: 0.0277 - accuracy: 0.9912 - val_loss: 1.5577 - val_accuracy: 0.7590
# Epoch 76/100
# 704/704 [==============================] - 54s 76ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 1.6599 - val_accuracy: 0.7536
# Epoch 77/100
# 704/704 [==============================] - 54s 76ms/step - loss: 0.0698 - accuracy: 0.9790 - val_loss: 1.5148 - val_accuracy: 0.7502
# Epoch 78/100
# 704/704 [==============================] - 54s 76ms/step - loss: 0.0169 - accuracy: 0.9946 - val_loss: 1.9416 - val_accuracy: 0.7094
# Epoch 79/100
# 704/704 [==============================] - 54s 76ms/step - loss: 0.0458 - accuracy: 0.9857 - val_loss: 1.6839 - val_accuracy: 0.7256
# Epoch 80/100
# 704/704 [==============================] - 54s 76ms/step - loss: 0.0425 - accuracy: 0.9869 - val_loss: 1.4493 - val_accuracy: 0.7616
# Epoch 81/100
# 704/704 [==============================] - 54s 76ms/step - loss: 0.0095 - accuracy: 0.9973 - val_loss: 1.6147 - val_accuracy: 0.7540
# Epoch 82/100
# 704/704 [==============================] - 54s 76ms/step - loss: 0.0190 - accuracy: 0.9947 - val_loss: 1.6633 - val_accuracy: 0.7438
# Epoch 83/100
# 704/704 [==============================] - 54s 76ms/step - loss: 0.0178 - accuracy: 0.9934 - val_loss: 1.6623 - val_accuracy: 0.7462
# Epoch 84/100
# 704/704 [==============================] - 54s 77ms/step - loss: 0.0357 - accuracy: 0.9891 - val_loss: 1.5384 - val_accuracy: 0.7600
# Epoch 85/100
# 704/704 [==============================] - 54s 77ms/step - loss: 0.0284 - accuracy: 0.9905 - val_loss: 1.6056 - val_accuracy: 0.7588
# Epoch 86/100
# 704/704 [==============================] - 54s 77ms/step - loss: 0.0162 - accuracy: 0.9949 - val_loss: 1.6029 - val_accuracy: 0.7576
# Epoch 87/100
# 704/704 [==============================] - 54s 77ms/step - loss: 0.0411 - accuracy: 0.9873 - val_loss: 2.0469 - val_accuracy: 0.7014
# Epoch 88/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0333 - accuracy: 0.9896 - val_loss: 1.7241 - val_accuracy: 0.7346
# Epoch 89/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0129 - accuracy: 0.9957 - val_loss: 1.6050 - val_accuracy: 0.7640
# Epoch 90/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0205 - accuracy: 0.9930 - val_loss: 2.0931 - val_accuracy: 0.7010
# Epoch 91/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0207 - accuracy: 0.9935 - val_loss: 1.7229 - val_accuracy: 0.7550
# Epoch 92/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0178 - accuracy: 0.9940 - val_loss: 1.7020 - val_accuracy: 0.7506
# Epoch 93/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0406 - accuracy: 0.9870 - val_loss: 1.6436 - val_accuracy: 0.7486
# Epoch 94/100
# 704/704 [==============================] - 53s 76ms/step - loss: 0.0228 - accuracy: 0.9921 - val_loss: 1.6094 - val_accuracy: 0.7514
# Epoch 95/100
# 704/704 [==============================] - 54s 76ms/step - loss: 0.0239 - accuracy: 0.9926 - val_loss: 1.9439 - val_accuracy: 0.7420
# Epoch 96/100
# 704/704 [==============================] - 54s 77ms/step - loss: 0.0115 - accuracy: 0.9962 - val_loss: 1.9223 - val_accuracy: 0.7406
# Epoch 97/100
# 704/704 [==============================] - 54s 76ms/step - loss: 0.0163 - accuracy: 0.9946 - val_loss: 1.6864 - val_accuracy: 0.7482
# Epoch 98/100
# 704/704 [==============================] - 54s 76ms/step - loss: 0.0731 - accuracy: 0.9809 - val_loss: 1.9867 - val_accuracy: 0.7194
# Epoch 99/100
# 704/704 [==============================] - 54s 76ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 1.6542 - val_accuracy: 0.7582
# Epoch 100/100
# 704/704 [==============================] - 54s 76ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 1.8761 - val_accuracy: 0.7450

# %%
preds = model.evaluate(X_test, y_test)
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
# 313/313 [==============================] - 5s 15ms/step - loss: 1.9324 - accuracy: 0.7408
# Loss = 1.932443380355835
# Test Accuracy = 0.7408000230789185

# %%
# Pandas and Numpy for data structures and util fucntions
import scipy as sp
import numpy as np
import pandas as pd
from numpy.random import rand
pd.options.display.max_colwidth = 600

# Scikit Imports
from sklearn import preprocessing
from sklearn.metrics import roc_curve, auc, precision_recall_curve
from sklearn.model_selection import train_test_split

# import cnn_utils as utils
# from model_evaluation_utils import get_metrics

# Matplot Imports
import matplotlib.pyplot as plt
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large'}

plt.rcParams.update(params)
# %matplotlib inline

# pandas display data frames as tables
from IPython.display import display, HTML

import warnings
warnings.filterwarnings('ignore')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
t = f.suptitle('Deep Neural Net Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epochs = list(range(1,100+1))
ax1.plot(epochs, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epochs, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(epochs)
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epochs, history.history['loss'], label='Train Loss')
ax2.plot(epochs, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(epochs)
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")
