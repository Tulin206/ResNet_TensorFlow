# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import cv2
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, Dropout, Flatten,Conv2D, MaxPooling2D,BatchNormalization,AveragePooling2D
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.python.keras.regularizers import l2
from tensorflow.keras.utils import plot_model
from IPython.display import SVG
# from tensorflow.keras.utils.vis_utils import model_to_dot
import tensorflow.keras.backend as K 
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load Data

(X_train, y_train), (X_test,y_test) = datasets.cifar10.load_data()

# %%
CLASS_NAMES= ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
X_train = X_train.astype('float32') / 255.
X_test = X_test.astype('float32') / 255.

# %%
#Train-validation-test split

X_val, y_val = X_train[:5000], y_train[:5000]
X_train, y_train = X_train[5000:], y_train[5000:]

# %%
#Onehot Encoding the labels.

from sklearn.utils.multiclass import unique_labels
from tensorflow.keras.utils import to_categorical

# %%
#Since we have 10 classes we should expect the shape[1] of y_train,y_val and y_test to change from 1 to 10

y_train=to_categorical(y_train)
y_val=to_categorical(y_val)
y_test=to_categorical(y_test)

# %%
# def add_noise_and_clip_data(data):
#    noise = np.random.normal(loc=0.0, scale=0.1, size=data.shape)
#    data = data + noise
#    data = np.clip(data, 0., 1.)
#    return data

# %%
# X_train_noisy = add_noise_and_clip_data(X_train)
# X_test_noisy = add_noise_and_clip_data(X_test)
# X_val_noisy = add_noise_and_clip_data(X_val)

# %%
# idx = 4
# plt.subplot(1,2,1)
# plt.imshow(X_train[idx])
# plt.title('Original image')
# plt.subplot(1,2,2)
# plt.imshow(X_train_noisy[idx])
# plt.title('Image with noise')
# plt.show()

# %%
#Image Data Augmentation

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_generator = ImageDataGenerator(rotation_range=2, horizontal_flip=True,zoom_range=.1 )

val_generator = ImageDataGenerator(rotation_range=2, horizontal_flip=True,zoom_range=.1)

test_generator = ImageDataGenerator(rotation_range=2, horizontal_flip= True,zoom_range=.1)

# %%
#Fitting the augmentation defined above to the data

train_generator.fit(X_train)
val_generator.fit(X_val)
# test_ds = test_generator.fit(X_test)

# %%
ROWS = 32
COLS = 32
CHANNELS = 3
CLASSES = 10

# %%
def identity_block(X, f, filters, stage, block):
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    # Retrieve Filters
    F1, F2, F3 = filters

    # Save the input value. We'll need this later to add back to the main path. 
    X_shortcut = X

    # First component of main path
    X = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2a', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    # Second component of main path
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path
    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
from tensorflow.python.framework import ops
ops.reset_default_graph()

# tf.reset_default_graph()

with tf.compat.v1.Session() as test:
    A_prev = tf.compat.v1.placeholder("float", [3, 4, 4, 6])
    X = np.random.randn(3, 4, 4, 6)
    A = identity_block(A_prev, f = 2, filters = [2, 4, 6], stage = 1, block = 'a')
    test.run(tf.compat.v1.global_variables_initializer())
    out = test.run([A], feed_dict={A_prev: X, K.learning_phase(): 0})
    print("out = ", out[0][1][1][0])
# Out:
# out =  [0.         0.         0.2924534  0.6707441  0.04589382 0.        ]

# %%
def convolutional_block(X, f, filters, stage, block, s = 2):
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X


    ##### MAIN PATH #####
    # First component of main path 
    X = Conv2D(F1, (1, 1), strides = (s,s), name = conv_name_base + '2a', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    # Second component of main path
    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path
    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    
    ##### SHORTCUT PATH ####
    X_shortcut = Conv2D(F3, (1, 1), strides = (s,s), name = conv_name_base + '1', kernel_initializer = glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3, name = bn_name_base + '1')(X_shortcut)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X

# %%
from tensorflow.python.framework import ops
ops.reset_default_graph()

# tf.reset_default_graph()

with tf.compat.v1.Session() as test:
    A_prev = tf.compat.v1.placeholder("float", [3, 4, 4, 6])
    X = np.random.randn(3, 4, 4, 6)
    A = convolutional_block(A_prev, f = 2, filters = [2, 4, 6], stage = 1, block = 'a')
    test.run(tf.compat.v1.global_variables_initializer())
    out = test.run([A], feed_dict={A_prev: X, K.learning_phase(): 0})
    print("out = ",out[0][1][1][0])
# Out:
# out =  [0.22215362 0.         0.         0.16444057 0.         0.        ]

# %%
def ResNet50(input_shape = (32, 32, 3), classes = 10):   
    global model
    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)
    
    # Stage 1
    X = Conv2D(64, (7, 7), strides = (2, 2), name = 'conv1', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convolutional_block(X, f = 3, filters = [64, 64, 256], stage = 2, block='a', s = 1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')

    # Stage 3
    X = convolutional_block(X, f = 3, filters = [128, 128, 512], stage = 3, block='a', s = 2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')

    # Stage 4
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], stage = 4, block='a', s = 2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')

    # Stage 5
    # X = convolutional_block(X, f = 3, filters = [512, 512, 2048], stage = 5, block='a', s = 2)
    # X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    # X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')

    # AVGPOOL.
    X = AveragePooling2D((2, 2), name='avg_pool')(X)

    # output layer
    X = Flatten()(X)
    # X = Dropout(0.5) (X)
    X = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = glorot_uniform(seed=0))(X)

    # Create model
    model = Model(inputs = X_input, outputs = X, name='ResNet50')

    model.summary()

    return model

# %%
model = ResNet50(input_shape = (32, 32, 3), classes = 10)
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 38, 38, 3)    0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 16, 16, 64)   9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 16, 16, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 16, 16, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 7, 7, 64)     0           activation_43[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 7, 7, 64)     4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 7, 7, 64)     256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 7, 7, 64)     0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 7, 7, 64)     36928       activation_44[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 7, 7, 64)     256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 7, 7, 64)     0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 7, 7, 256)    16640       activation_45[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 7, 7, 256)    16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 7, 7, 256)    1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 7, 7, 256)    1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 7, 7, 256)    0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 7, 7, 256)    0           add_14[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 7, 7, 64)     16448       activation_46[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 7, 7, 64)     256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 7, 7, 64)     0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 7, 7, 64)     36928       activation_47[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 7, 7, 64)     256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 7, 7, 64)     0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 7, 7, 256)    16640       activation_48[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 7, 7, 256)    1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 7, 7, 256)    0           bn2b_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 7, 7, 256)    0           add_15[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 7, 7, 64)     16448       activation_49[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 7, 7, 64)     256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 7, 7, 64)     0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 7, 7, 64)     36928       activation_50[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 7, 7, 64)     256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 7, 7, 64)     0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 7, 7, 256)    16640       activation_51[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 7, 7, 256)    1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 7, 7, 256)    0           bn2c_branch2c[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 7, 7, 256)    0           add_16[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 4, 4, 128)    32896       activation_52[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 4, 4, 128)    512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 4, 4, 128)    0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 4, 4, 128)    147584      activation_53[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 4, 4, 128)    512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 4, 4, 128)    0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 4, 4, 512)    66048       activation_54[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 4, 4, 512)    131584      activation_52[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 4, 4, 512)    2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 4, 4, 512)    2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 4, 4, 512)    0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 4, 4, 512)    0           add_17[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 4, 4, 128)    65664       activation_55[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 4, 4, 128)    512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 4, 4, 128)    0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 4, 4, 128)    147584      activation_56[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 4, 4, 128)    512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 4, 4, 128)    0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 4, 4, 512)    66048       activation_57[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 4, 4, 512)    2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 4, 4, 512)    0           bn3b_branch2c[0][0]
#                                                                  activation_55[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 4, 4, 512)    0           add_18[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 4, 4, 128)    65664       activation_58[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 4, 4, 128)    512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 4, 4, 128)    0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 4, 4, 128)    147584      activation_59[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 4, 4, 128)    512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 4, 4, 128)    0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 4, 4, 512)    66048       activation_60[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 4, 4, 512)    2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 4, 4, 512)    0           bn3c_branch2c[0][0]
#                                                                  activation_58[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 4, 4, 512)    0           add_19[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 4, 4, 128)    65664       activation_61[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 4, 4, 128)    512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 4, 4, 128)    0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 4, 4, 128)    147584      activation_62[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 4, 4, 128)    512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 4, 4, 128)    0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 4, 4, 512)    66048       activation_63[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 4, 4, 512)    2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 4, 4, 512)    0           bn3d_branch2c[0][0]
#                                                                  activation_61[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 4, 4, 512)    0           add_20[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 2, 2, 256)    131328      activation_64[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 2, 2, 256)    1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 2, 2, 256)    0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 2, 2, 256)    590080      activation_65[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 2, 2, 256)    1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 2, 2, 256)    0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 2, 2, 1024)   263168      activation_66[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 2, 2, 1024)   525312      activation_64[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 2, 2, 1024)   4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 2, 2, 1024)   4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 2, 2, 1024)   0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 2, 2, 1024)   0           add_21[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 2, 2, 256)    262400      activation_67[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 2, 2, 256)    1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 2, 2, 256)    0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 2, 2, 256)    590080      activation_68[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 2, 2, 256)    1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 2, 2, 256)    0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 2, 2, 1024)   263168      activation_69[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 2, 2, 1024)   4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 2, 2, 1024)   0           bn4b_branch2c[0][0]
#                                                                  activation_67[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 2, 2, 1024)   0           add_22[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 2, 2, 256)    262400      activation_70[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 2, 2, 256)    1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 2, 2, 256)    0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 2, 2, 256)    590080      activation_71[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 2, 2, 256)    1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 2, 2, 256)    0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 2, 2, 1024)   263168      activation_72[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 2, 2, 1024)   4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 2, 2, 1024)   0           bn4c_branch2c[0][0]
#                                                                  activation_70[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 2, 2, 1024)   0           add_23[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 2, 2, 256)    262400      activation_73[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 2, 2, 256)    1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 2, 2, 256)    0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 2, 2, 256)    590080      activation_74[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 2, 2, 256)    1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 2, 2, 256)    0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 2, 2, 1024)   263168      activation_75[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 2, 2, 1024)   4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 2, 2, 1024)   0           bn4d_branch2c[0][0]
#                                                                  activation_73[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 2, 2, 1024)   0           add_24[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 2, 2, 256)    262400      activation_76[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 2, 2, 256)    1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 2, 2, 256)    0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 2, 2, 256)    590080      activation_77[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 2, 2, 256)    1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 2, 2, 256)    0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 2, 2, 1024)   263168      activation_78[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 2, 2, 1024)   4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 2, 2, 1024)   0           bn4e_branch2c[0][0]
#                                                                  activation_76[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 2, 2, 1024)   0           add_25[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 2, 2, 256)    262400      activation_79[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 2, 2, 256)    1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 2, 2, 256)    0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 2, 2, 256)    590080      activation_80[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 2, 2, 256)    1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 2, 2, 256)    0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 2, 2, 1024)   263168      activation_81[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 2, 2, 1024)   4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 2, 2, 1024)   0           bn4f_branch2c[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 2, 2, 1024)   0           add_26[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 1024)   0           activation_82[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1024)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# fc10 (Dense)                    (None, 10)           10250       flatten_1[0][0]
# ==================================================================================================
# Total params: 8,599,434
# Trainable params: 8,568,842
# Non-trainable params: 30,592
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate = 0.0001, momentum = 0.9, nesterov = False), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_generator.flow(X_train, y_train, batch_size=32), 
                    epochs = 100,
                    batch_size = 64,
                    validation_data = val_generator.flow(X_val, y_val, batch_size=32))
# Out:
# Epoch 1/100
# 1407/1407 [==============================] - 107s 72ms/step - loss: 94.2874 - accuracy: 0.2050 - val_loss: 89.7046 - val_accuracy: 0.3536
# Epoch 2/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 88.4561 - accuracy: 0.3719 - val_loss: 84.7074 - val_accuracy: 0.4296
# Epoch 3/100
# 1407/1407 [==============================] - 101s 71ms/step - loss: 83.5541 - accuracy: 0.4290 - val_loss: 80.0865 - val_accuracy: 0.4574
# Epoch 4/100
# 1407/1407 [==============================] - 99s 71ms/step - loss: 78.9829 - accuracy: 0.4598 - val_loss: 75.7812 - val_accuracy: 0.4764
# Epoch 5/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 74.6748 - accuracy: 0.4904 - val_loss: 71.6808 - val_accuracy: 0.4956
# Epoch 6/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 70.6225 - accuracy: 0.5120 - val_loss: 67.7297 - val_accuracy: 0.5288
# Epoch 7/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 66.7835 - accuracy: 0.5313 - val_loss: 64.1896 - val_accuracy: 0.4888
# Epoch 8/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 63.1653 - accuracy: 0.5443 - val_loss: 60.5756 - val_accuracy: 0.5590
# Epoch 9/100
# 1407/1407 [==============================] - 99s 71ms/step - loss: 59.7459 - accuracy: 0.5591 - val_loss: 57.4063 - val_accuracy: 0.5378
# Epoch 10/100
# 1407/1407 [==============================] - 99s 71ms/step - loss: 56.5037 - accuracy: 0.5737 - val_loss: 54.3652 - val_accuracy: 0.5390
# Epoch 11/100
# 1407/1407 [==============================] - 99s 71ms/step - loss: 53.4376 - accuracy: 0.5921 - val_loss: 51.5079 - val_accuracy: 0.5260
# Epoch 12/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 50.5552 - accuracy: 0.6073 - val_loss: 48.5583 - val_accuracy: 0.5836
# Epoch 13/100
# 1407/1407 [==============================] - 99s 71ms/step - loss: 47.8248 - accuracy: 0.6143 - val_loss: 45.9815 - val_accuracy: 0.5898
# Epoch 14/100
# 1407/1407 [==============================] - 99s 71ms/step - loss: 45.2302 - accuracy: 0.6322 - val_loss: 43.5223 - val_accuracy: 0.5982
# Epoch 15/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 42.8015 - accuracy: 0.6379 - val_loss: 41.2166 - val_accuracy: 0.6016
# Epoch 16/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 40.4962 - accuracy: 0.6484 - val_loss: 38.9924 - val_accuracy: 0.6074
# Epoch 17/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 38.3179 - accuracy: 0.6565 - val_loss: 36.8738 - val_accuracy: 0.6302
# Epoch 18/100
# 1407/1407 [==============================] - 99s 71ms/step - loss: 36.2565 - accuracy: 0.6666 - val_loss: 34.9039 - val_accuracy: 0.6344
# Epoch 19/100
# 1407/1407 [==============================] - 99s 71ms/step - loss: 34.3005 - accuracy: 0.6769 - val_loss: 33.1510 - val_accuracy: 0.6050
# Epoch 20/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 32.4519 - accuracy: 0.6907 - val_loss: 31.5821 - val_accuracy: 0.5696
# Epoch 21/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 30.7131 - accuracy: 0.6985 - val_loss: 29.6244 - val_accuracy: 0.6506
# Epoch 22/100
# 1407/1407 [==============================] - 99s 71ms/step - loss: 29.0681 - accuracy: 0.7053 - val_loss: 28.1604 - val_accuracy: 0.6268
# Epoch 23/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 27.5121 - accuracy: 0.7136 - val_loss: 26.6297 - val_accuracy: 0.6532
# Epoch 24/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 26.0434 - accuracy: 0.7200 - val_loss: 25.4486 - val_accuracy: 0.6024
# Epoch 25/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 24.6555 - accuracy: 0.7246 - val_loss: 23.9964 - val_accuracy: 0.6322
# Epoch 26/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 23.3321 - accuracy: 0.7365 - val_loss: 22.6908 - val_accuracy: 0.6480
# Epoch 27/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 22.0917 - accuracy: 0.7438 - val_loss: 21.4574 - val_accuracy: 0.6694
# Epoch 28/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 20.9221 - accuracy: 0.7480 - val_loss: 20.4084 - val_accuracy: 0.6552
# Epoch 29/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 19.8007 - accuracy: 0.7584 - val_loss: 19.3719 - val_accuracy: 0.6572
# Epoch 30/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 18.7632 - accuracy: 0.7632 - val_loss: 18.3449 - val_accuracy: 0.6684
# Epoch 31/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 17.7767 - accuracy: 0.7666 - val_loss: 17.4487 - val_accuracy: 0.6564
# Epoch 32/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 16.8386 - accuracy: 0.7717 - val_loss: 16.5721 - val_accuracy: 0.6560
# Epoch 33/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 15.9437 - accuracy: 0.7822 - val_loss: 15.7730 - val_accuracy: 0.6502
# Epoch 34/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 15.1131 - accuracy: 0.7864 - val_loss: 14.8811 - val_accuracy: 0.6726
# Epoch 35/100
# 1407/1407 [==============================] - 102s 72ms/step - loss: 14.3260 - accuracy: 0.7877 - val_loss: 14.2727 - val_accuracy: 0.6534
# Epoch 36/100
# 1407/1407 [==============================] - 102s 72ms/step - loss: 13.5773 - accuracy: 0.7940 - val_loss: 13.5522 - val_accuracy: 0.6438
# Epoch 37/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 12.8574 - accuracy: 0.8012 - val_loss: 12.9276 - val_accuracy: 0.6394
# Epoch 38/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 12.1990 - accuracy: 0.8044 - val_loss: 12.1733 - val_accuracy: 0.6866
# Epoch 39/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 11.5610 - accuracy: 0.8103 - val_loss: 11.5050 - val_accuracy: 0.7008
# Epoch 40/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 10.9840 - accuracy: 0.8110 - val_loss: 10.9706 - val_accuracy: 0.6900
# Epoch 41/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 10.4071 - accuracy: 0.8195 - val_loss: 10.4782 - val_accuracy: 0.6824
# Epoch 42/100
# 1407/1407 [==============================] - 101s 71ms/step - loss: 9.8733 - accuracy: 0.8276 - val_loss: 9.9977 - val_accuracy: 0.6806
# Epoch 43/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 9.3714 - accuracy: 0.8292 - val_loss: 9.5416 - val_accuracy: 0.6868
# Epoch 44/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 8.9071 - accuracy: 0.8297 - val_loss: 9.0665 - val_accuracy: 0.6934
# Epoch 45/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 8.4520 - accuracy: 0.8306 - val_loss: 8.6538 - val_accuracy: 0.6944
# Epoch 46/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 8.0339 - accuracy: 0.8353 - val_loss: 8.2482 - val_accuracy: 0.7030
# Epoch 47/100
# 1407/1407 [==============================] - 101s 71ms/step - loss: 7.6249 - accuracy: 0.8407 - val_loss: 7.8350 - val_accuracy: 0.7020
# Epoch 48/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 7.2450 - accuracy: 0.8470 - val_loss: 7.5847 - val_accuracy: 0.6786
# Epoch 49/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 6.8915 - accuracy: 0.8488 - val_loss: 7.1241 - val_accuracy: 0.7130
# Epoch 50/100
# 1407/1407 [==============================] - 98s 70ms/step - loss: 6.5570 - accuracy: 0.8498 - val_loss: 6.8754 - val_accuracy: 0.6986
# Epoch 51/100
# 1407/1407 [==============================] - 99s 70ms/step - loss: 6.2373 - accuracy: 0.8503 - val_loss: 6.9642 - val_accuracy: 0.6140
# Epoch 52/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 5.9333 - accuracy: 0.8565 - val_loss: 6.4008 - val_accuracy: 0.6766
# Epoch 53/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 5.6530 - accuracy: 0.8545 - val_loss: 6.0023 - val_accuracy: 0.7090
# Epoch 54/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 5.3779 - accuracy: 0.8639 - val_loss: 5.7447 - val_accuracy: 0.7180
# Epoch 55/100
# 1407/1407 [==============================] - 98s 70ms/step - loss: 5.1297 - accuracy: 0.8624 - val_loss: 5.5884 - val_accuracy: 0.6918
# Epoch 56/100
# 1407/1407 [==============================] - 98s 70ms/step - loss: 4.8924 - accuracy: 0.8631 - val_loss: 5.2555 - val_accuracy: 0.7160
# Epoch 57/100
# 1407/1407 [==============================] - 98s 70ms/step - loss: 4.6598 - accuracy: 0.8677 - val_loss: 5.0549 - val_accuracy: 0.7276
# Epoch 58/100
# 1407/1407 [==============================] - 98s 70ms/step - loss: 4.4403 - accuracy: 0.8740 - val_loss: 4.9174 - val_accuracy: 0.7032
# Epoch 59/100
# 1407/1407 [==============================] - 99s 70ms/step - loss: 4.2334 - accuracy: 0.8758 - val_loss: 4.6857 - val_accuracy: 0.7096
# Epoch 60/100
# 1407/1407 [==============================] - 99s 70ms/step - loss: 4.0535 - accuracy: 0.8777 - val_loss: 4.6441 - val_accuracy: 0.6912
# Epoch 61/100
# 1407/1407 [==============================] - 101s 71ms/step - loss: 3.8619 - accuracy: 0.8826 - val_loss: 4.4111 - val_accuracy: 0.7072
# Epoch 62/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 3.6968 - accuracy: 0.8825 - val_loss: 4.2375 - val_accuracy: 0.7004
# Epoch 63/100
# 1407/1407 [==============================] - 101s 71ms/step - loss: 3.5237 - accuracy: 0.8857 - val_loss: 4.0496 - val_accuracy: 0.7184
# Epoch 64/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 3.3812 - accuracy: 0.8849 - val_loss: 3.9302 - val_accuracy: 0.7060
# Epoch 65/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 3.2364 - accuracy: 0.8864 - val_loss: 3.7364 - val_accuracy: 0.7184
# Epoch 66/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 3.1093 - accuracy: 0.8828 - val_loss: 3.6848 - val_accuracy: 0.7048
# Epoch 67/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 2.9669 - accuracy: 0.8922 - val_loss: 3.5165 - val_accuracy: 0.7084
# Epoch 68/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 2.8466 - accuracy: 0.8930 - val_loss: 3.3722 - val_accuracy: 0.7322
# Epoch 69/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 2.7394 - accuracy: 0.8874 - val_loss: 3.2982 - val_accuracy: 0.7254
# Epoch 70/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 2.6242 - accuracy: 0.8946 - val_loss: 3.2113 - val_accuracy: 0.7116
# Epoch 71/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 2.5121 - accuracy: 0.8973 - val_loss: 3.2144 - val_accuracy: 0.7082
# Epoch 72/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 2.4264 - accuracy: 0.8937 - val_loss: 2.9645 - val_accuracy: 0.7380
# Epoch 73/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 2.3239 - accuracy: 0.8988 - val_loss: 2.8747 - val_accuracy: 0.7316
# Epoch 74/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 2.2396 - accuracy: 0.9005 - val_loss: 2.9251 - val_accuracy: 0.7048
# Epoch 75/100
# 1407/1407 [==============================] - 101s 71ms/step - loss: 2.1623 - accuracy: 0.8987 - val_loss: 2.7351 - val_accuracy: 0.7414
# Epoch 76/100
# 1407/1407 [==============================] - 101s 71ms/step - loss: 2.0829 - accuracy: 0.9009 - val_loss: 2.7929 - val_accuracy: 0.7154
# Epoch 77/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 2.0156 - accuracy: 0.8988 - val_loss: 2.6719 - val_accuracy: 0.7242
# Epoch 78/100
# 1407/1407 [==============================] - 101s 71ms/step - loss: 1.9429 - accuracy: 0.9038 - val_loss: 2.5769 - val_accuracy: 0.7308
# Epoch 79/100
# 1407/1407 [==============================] - 101s 71ms/step - loss: 1.8693 - accuracy: 0.9062 - val_loss: 2.4546 - val_accuracy: 0.7414
# Epoch 80/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 1.7996 - accuracy: 0.9100 - val_loss: 2.6566 - val_accuracy: 0.6752
# Epoch 81/100
# 1407/1407 [==============================] - 102s 72ms/step - loss: 1.7585 - accuracy: 0.9045 - val_loss: 2.6058 - val_accuracy: 0.6870
# Epoch 82/100
# 1407/1407 [==============================] - 102s 72ms/step - loss: 1.7047 - accuracy: 0.9047 - val_loss: 2.4259 - val_accuracy: 0.7120
# Epoch 83/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 1.6482 - accuracy: 0.9076 - val_loss: 2.2705 - val_accuracy: 0.7448
# Epoch 84/100
# 1407/1407 [==============================] - 101s 71ms/step - loss: 1.5923 - accuracy: 0.9091 - val_loss: 2.4806 - val_accuracy: 0.6872
# Epoch 85/100
# 1407/1407 [==============================] - 101s 71ms/step - loss: 1.5477 - accuracy: 0.9117 - val_loss: 2.3441 - val_accuracy: 0.7016
# Epoch 86/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 1.5083 - accuracy: 0.9075 - val_loss: 2.1954 - val_accuracy: 0.7274
# Epoch 87/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 1.4468 - accuracy: 0.9174 - val_loss: 2.4375 - val_accuracy: 0.6480
# Epoch 88/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 1.4217 - accuracy: 0.9103 - val_loss: 2.1983 - val_accuracy: 0.7138
# Epoch 89/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 1.3780 - accuracy: 0.9166 - val_loss: 2.1902 - val_accuracy: 0.7150
# Epoch 90/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 1.3347 - accuracy: 0.9174 - val_loss: 1.9379 - val_accuracy: 0.7480
# Epoch 91/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 1.3031 - accuracy: 0.9173 - val_loss: 2.2751 - val_accuracy: 0.6642
# Epoch 92/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 1.2710 - accuracy: 0.9179 - val_loss: 1.9966 - val_accuracy: 0.7238
# Epoch 93/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 1.2404 - accuracy: 0.9183 - val_loss: 1.8513 - val_accuracy: 0.7532
# Epoch 94/100
# 1407/1407 [==============================] - 101s 71ms/step - loss: 1.2131 - accuracy: 0.9175 - val_loss: 1.9973 - val_accuracy: 0.7162
# Epoch 95/100
# 1407/1407 [==============================] - 101s 71ms/step - loss: 1.1815 - accuracy: 0.9199 - val_loss: 2.0266 - val_accuracy: 0.7126
# Epoch 96/100
# 1407/1407 [==============================] - 101s 72ms/step - loss: 1.1492 - accuracy: 0.9223 - val_loss: 1.7525 - val_accuracy: 0.7662
# Epoch 97/100
# 1407/1407 [==============================] - 100s 71ms/step - loss: 1.1260 - accuracy: 0.9235 - val_loss: 1.9291 - val_accuracy: 0.7228
# Epoch 98/100
# 1407/1407 [==============================] - 99s 70ms/step - loss: 1.0995 - accuracy: 0.9237 - val_loss: 1.9676 - val_accuracy: 0.7156
# Epoch 99/100
# 1407/1407 [==============================] - 99s 70ms/step - loss: 1.0788 - accuracy: 0.9249 - val_loss: 1.9451 - val_accuracy: 0.7084
# Epoch 100/100
# 1407/1407 [==============================] - 99s 70ms/step - loss: 1.0601 - accuracy: 0.9230 - val_loss: 1.7376 - val_accuracy: 0.7470

# %%
preds = model.evaluate(X_test, y_test)
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
# 313/313 [==============================] - 7s 19ms/step - loss: 1.7115 - accuracy: 0.7501
# Loss = 1.7114640474319458
# Test Accuracy = 0.7501000165939331

# %%
# Pandas and Numpy for data structures and util fucntions
import scipy as sp
import numpy as np
import pandas as pd
from numpy.random import rand
pd.options.display.max_colwidth = 600

# Scikit Imports
from sklearn import preprocessing
from sklearn.metrics import roc_curve, auc, precision_recall_curve
from sklearn.model_selection import train_test_split

# import cnn_utils as utils
# from model_evaluation_utils import get_metrics

# Matplot Imports
import matplotlib.pyplot as plt
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large'}

plt.rcParams.update(params)
# %matplotlib inline

# pandas display data frames as tables
from IPython.display import display, HTML

import warnings
warnings.filterwarnings('ignore')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
t = f.suptitle('Deep Neural Net Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epochs = list(range(1,100+1))
ax1.plot(epochs, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epochs, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(epochs)
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epochs, history.history['loss'], label='Train Loss')
ax2.plot(epochs, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(epochs)
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")
